# %%
from google.colab import drive
drive.mount("/gdrive", force_remount=True)
# Out:
# Mounted at /gdrive

# %%
import numpy as np
import torch

# 데이터 읽기 함수
def load_dataset(file):

  data = np.loadtxt(file)
  print("DATA=",data)
  
  x = data[:,0:-1]
  print("X=",x)
  
  y = np.reshape(data[:,-1],(3,1))
  print("Y=",y)
 
  # 텐서로 변경
  # 이곳을 채우세요.
  x = torch.tensor(x,dtype=torch.float)

  # x = torch.tensor(x, dtype=torch.float)
  # y = torch.tensor(y, dtype=torch.float)


  return (x, y)

# 텐서를 리스트로 바꾸는 함수
def tensor2list(input_tensor):
  return input_tensor.cpu().detach().numpy().tolist()

x, y = load_dataset("/gdrive/My Drive/colab/gda/train.txt")

# 가중치 초기화
w = torch.randn(1)*3.0
print("\nInit: w = {0}\n".format(tensor2list(w)))

# 학습률
alpha = 0.1

# 학습데이터 수
m = y.size(0)

for epoch in range(50):
  cost = 0

  for i in range(m):
    # 이곳을 채우세요.
    cost = cost + ((w * x[i]) - y[i]) * x[i]

  cost = 1/m * cost
  w = w - alpha * cost

  # 이곳을 채우세요.
  
  print("Epoch {0:d}: w = {1}".format(epoch+1,tensor2list(w)))
# Out:
# DATA= [[1. 1.]
#  [2. 2.]
#  [3. 3.]]
# X= [[1.]
#  [2.]
#  [3.]]
# Y= [[1.]
#  [2.]
#  [3.]]
#
# Init: w = [2.943049430847168]
#
# Epoch 1: w = [2.0362930297851562]
# Epoch 2: w = [1.552689552307129]
# Epoch 3: w = [1.2947677373886108]
# Epoch 4: w = [1.1572095155715942]
# Epoch 5: w = [1.0838450193405151]
# Epoch 6: w = [1.0447173118591309]
# Epoch 7: w = [1.0238492488861084]
# Epoch 8: w = [1.0127196311950684]
# Epoch 9: w = [1.0067838430404663]
# Epoch 10: w = [1.0036180019378662]
# Epoch 11: w = [1.0019296407699585]
# Epoch 12: w = [1.001029133796692]
# Epoch 13: w = [1.0005488395690918]
# Epoch 14: w = [1.0002926588058472]
# Epoch 15: w = [1.000156044960022]
# Epoch 16: w = [1.0000832080841064]
# Epoch 17: w = [1.000044345855713]
# Epoch 18: w = [1.000023603439331]
# Epoch 19: w = [1.0000126361846924]
# Epoch 20: w = [1.0000067949295044]
# Epoch 21: w = [1.0000035762786865]
# Epoch 22: w = [1.0000019073486328]
# Epoch 23: w = [1.000001072883606]
# Epoch 24: w = [1.0000005960464478]
# Epoch 25: w = [1.0000003576278687]
# Epoch 26: w = [1.000000238418579]
# Epoch 27: w = [1.0000001192092896]
# Epoch 28: w = [1.0]
# Epoch 29: w = [1.0]
# Epoch 30: w = [1.0]
# Epoch 31: w = [1.0]
# Epoch 32: w = [1.0]
# Epoch 33: w = [1.0]
# Epoch 34: w = [1.0]
# Epoch 35: w = [1.0]
# Epoch 36: w = [1.0]
# Epoch 37: w = [1.0]
# Epoch 38: w = [1.0]
# Epoch 39: w = [1.0]
# Epoch 40: w = [1.0]
# Epoch 41: w = [1.0]
# Epoch 42: w = [1.0]
# Epoch 43: w = [1.0]
# Epoch 44: w = [1.0]
# Epoch 45: w = [1.0]
# Epoch 46: w = [1.0]
# Epoch 47: w = [1.0]
# Epoch 48: w = [1.0]
# Epoch 49: w = [1.0]
# Epoch 50: w = [1.0]
